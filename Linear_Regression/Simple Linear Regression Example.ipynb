# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,10,100)

y = 4.9 + 3.8*x + np.random.randn(100)

# %%
plt.figure(figsize = (12,9))
plt.scatter(x, y)

# %%
d = np.mean(x**2) - np.mean(x)**2

w0 = (np.mean(y)*np.mean(x**2) - np.mean(x)*np.mean(x*y)) / d
w1 = (np.mean(x*y) - np.mean(x)*np.mean(y)) / d

y_hat = w0 + w1*x

# %%
plt.figure(figsize = (12,9))
plt.scatter(x, y)
plt.plot(x, y_hat, color = "black", linewidth = 2)

# %%
r2 = 1 - np.sum((y - y_hat)**2)/np.sum((y - y.mean())**2)

print("R-squared: {}".format(r2))
# Out:
# R-squared: 0.9898612415802827

# %%
np.abs(y - y_hat) / y
# Out:
# array([0.281685  , 0.19244599, 0.05950964, 0.16245235, 0.09743063,
#        0.1094395 , 0.00262158, 0.28097602, 0.00279894, 0.18234468,
#        0.09253859, 0.12590959, 0.01075859, 0.01426886, 0.01443091,
#        0.04906459, 0.01408279, 0.00038363, 0.05944571, 0.05139833,
#        0.10470015, 0.00040345, 0.02257743, 0.04933055, 0.01385433,
#        0.04686302, 0.04127157, 0.13736326, 0.03378049, 0.16644889,
#        0.12245231, 0.08806017, 0.15777808, 0.08910585, 0.04716188,
#        0.01043384, 0.08848683, 0.02024053, 0.01359422, 0.06349404,
#        0.05580657, 0.03193914, 0.03726606, 0.05411053, 0.04370303,
#        0.05084015, 0.1004617 , 0.02896704, 0.07400875, 0.02337399,
#        0.02144998, 0.05134194, 0.03565288, 0.01699161, 0.04512657,
#        0.00772649, 0.00594729, 0.06102757, 0.00900004, 0.07963799,
#        0.06051613, 0.05127581, 0.00834547, 0.00191827, 0.02772049,
#        0.04848656, 0.02082484, 0.04847053, 0.02485173, 0.05657403,
#        0.01192994, 0.00238557, 0.003808  , 0.00105787, 0.02154218,
#        0.04488397, 0.01014344, 0.01938528, 0.03738876, 0.04865717,
#        0.06683228, 0.04263338, 0.02911285, 0.03454914, 0.04415541,
#        0.00678093, 0.00590065, 0.03911811, 0.02853849, 0.00937469,
#        0.00781409, 0.00190824, 0.02886955, 0.00624978, 0.00516639,
#        0.05976578, 0.04319569, 0.01676045, 0.00653734, 0.02215622])
